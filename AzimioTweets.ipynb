# %% [markdown]
# Twitter Analysis for the top political candidates/parties in Kenya. Raila/Azimio, Ruto/UDA, Wajackoyah/Roots Party
#
# The purpose of this analysis is to determine:
# 1 Which is the candidate with the most tweets, period- between the election date and the current date?
# 2 Tweet with the most likes, what was it about? Who tweeted it?
# 3 Tweet with the most retweets, what was it about? Who tweeted it?

# %%
#import libraries to scrape data and create the dataframe to store our data
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# Set query
query = "(#Raila OR #Azimio) until:2022-09-04 since:2022-08-09"
tweets = []
limit = 40000

# %%
# Define the step to source our data
for tweet in sntwitter.TwitterHashtagScraper(query).get_items():
    if len(tweets)==limit:
        break
    else:
        tweets.append([tweet.date, tweet.url, tweet.user.username, tweet.sourceLabel, tweet.user.location, tweet.content, tweet.likeCount, tweet.retweetCount, tweet.quoteCount, tweet.replyCount])
df = pd.DataFrame(tweets, columns = ['Date', 'TweetURL','User', 'Source', 'Location', 'Tweet', 'Likes_Count','Retweet_Count', 'Quote_Count', 'Reply_Count'])
df.to_csv("Azimio-Tweets.csv")

# %%
df.head()
# Out:
#                        Date  \
# 0 2022-09-03 22:07:42+00:00
# 1 2022-09-03 21:45:15+00:00
# 2 2022-09-03 21:24:32+00:00
# 3 2022-09-03 19:34:16+00:00
# 4 2022-09-03 19:17:35+00:00
#
#                                             TweetURL             User  \
# 0  https://twitter.com/Luke79345686/status/156618...     Luke79345686
# 1  https://twitter.com/Luke79345686/status/156618...     Luke79345686
# 2  https://twitter.com/victoroduorany2/status/156...  victoroduorany2
# 3  https://twitter.com/Osoro20Fred/status/1566147...      Osoro20Fred
# 4  https://twitter.com/Sily951/status/15661433849...          Sily951
#
#                 Source          Location  \
# 0  Twitter for Android
# 1  Twitter for Android
# 2  Twitter for Android    Nairobi, Kenya
# 3  Twitter for Android  Kiamokama, Kenya
# 4   Twitter for iPhone
#
#                                                Tweet  Likes_Count  \
# 0  @chrisotee @EtalePhilip #Azimio never bothered...            1
# ...

# %%
print("Number of rows :", df.shape[0],"Number of columns:", df.shape[1])
# Out:
# Number of rows : 4265 Number of columns: 10

# %%
df.describe()
# Out:
#        Likes_Count  Retweet_Count  Quote_Count  Reply_Count
# count  4265.000000    4265.000000  4265.000000  4265.000000
# mean      7.222040       0.991794     0.060023     0.564361
# std      65.370902       7.990301     0.523517     5.477152
# min       0.000000       0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000
# 50%       1.000000       0.000000     0.000000     0.000000
# 75%       2.000000       0.000000     0.000000     0.000000
# max    2333.000000     304.000000    17.000000   191.000000
